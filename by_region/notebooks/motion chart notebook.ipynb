# %% [markdown]
# # Motion Charts in Python with Pandas

# %% [markdown]
# Hans Olav Melberg (hans.melberg@gmail.com), 17. October, 2015

# %% [markdown]
# ## Import modules

# %%
from motionchart.motionchart import MotionChart, MotionChartDemo
import webbrowser
import pandas as pd
import pyperclip
df=pd.read_csv('C:/Users/nailt/Downloads/asasas.csv')

# %%
df = df.drop('Delivery Quality', 1)

# %% [markdown]
# Install if necessary, using "pip install motionchart"

# %% [markdown]
# ## Define dataframe

# %%
df
# Out:
#      Year               Country                           Region  Happiness
# 0    2015           Switzerland                   Western Europe       7587
# 1    2015               Iceland                   Western Europe       7561
# 2    2015               Denmark                   Western Europe       7527
# 3    2015                Norway                   Western Europe       7522
# 4    2015                Canada                    North America       7427
# 5    2015               Finland                   Western Europe       7406
# 6    2015           Netherlands                   Western Europe       7378
# 7    2015                Sweden                   Western Europe       7364
# 8    2015           New Zealand        Australia and New Zealand       7286
# 9    2015             Australia        Australia and New Zealand       7284
# 10   2015                Israel  Middle East and Northern Africa       7278
# 11   2015            Costa Rica      Latin America and Caribbean       7226
# 12   2015               Austria                   Western Europe         72
# 13   2015                Mexico      Latin America and Caribbean       7187
# 14   2015         United States                    North America       7119
# 15   2015                Brazil      Latin America and Caribbean       6983
# 16   2015            Luxembourg                   Western Europe       6946
# 17   2015               Ireland                   Western Europe        694
# 18   2015               Belgium                   Western Europe       6937
# 19   2015  United Arab Emirates  Middle East and Northern Africa       6901
# 20   2015        United Kingdom                   Western Europe       6867
# 21   2015                  Oman  Middle East and Northern Africa       6853
# 22   2015             Venezuela      Latin America and Caribbean        681
# 23   2015             Singapore                Southeastern Asia       6798
# 24   2015                Panama      Latin America and Caribbean       6786
# 25   2015               Germany                   Western Europe        675
# 26   2015                 Chile      Latin America and Caribbean        667
# 27   2015                 Qatar  Middle East and Northern Africa       6611
# 28   2015                France                   Western Europe       6575
# 29   2015             Argentina      Latin America and Caribbean       6574
# ..    ...                   ...                              ...        ...
# 285  2016               Senegal               Sub-Saharan Africa       4219
# 286  2016              Bulgaria       Central and Eastern Europe       4217
# 287  2016            Mauritania               Sub-Saharan Africa       4201
# 288  2016              Zimbabwe               Sub-Saharan Africa       4193
# 289  2016                Malawi               Sub-Saharan Africa       4156
# 290  2016                 Sudan               Sub-Saharan Africa       4139
# 291  2016                 Gabon               Sub-Saharan Africa       4121
# 292  2016                  Mali               Sub-Saharan Africa       4073
# 293  2016                 Haiti      Latin America and Caribbean       4028
# 294  2016              Botswana               Sub-Saharan Africa       3974
# 295  2016               Comoros               Sub-Saharan Africa       3956
# 296  2016           Ivory Coast               Sub-Saharan Africa       3916
# 297  2016              Cambodia                Southeastern Asia       3907
# 298  2016                Angola               Sub-Saharan Africa       3866
# 299  2016                 Niger               Sub-Saharan Africa       3856
# 300  2016           South Sudan               Sub-Saharan Africa       3832
# 301  2016                  Chad               Sub-Saharan Africa       3763
# 302  2016          Burkina Faso               Sub-Saharan Africa       3739
# 303  2016                Uganda               Sub-Saharan Africa       3739
# 304  2016                 Yemen  Middle East and Northern Africa       3724
# 305  2016            Madagascar               Sub-Saharan Africa       3695
# 306  2016              Tanzania               Sub-Saharan Africa       3666
# 307  2016               Liberia               Sub-Saharan Africa       3622
# 308  2016                Guinea               Sub-Saharan Africa       3607
# 309  2016                Rwanda               Sub-Saharan Africa       3515
# 310  2016                 Benin               Sub-Saharan Africa       3484
# 311  2016           Afghanistan                    Southern Asia        336
# 312  2016                  Togo               Sub-Saharan Africa       3303
# 313  2016                 Syria  Middle East and Northern Africa       3069
# 314  2016               Burundi               Sub-Saharan Africa       2905
#
# [315 rows x 4 columns]

# %% [markdown]
# ## Create and show MotionChart

# %%
mChart = MotionChart(df = df)
mChart.to_notebook()
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="mc_temp.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Demo

# %%
motionChartDemo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-97aff12a3721> in <module>()
# ----> 1 motionChartDemo()
#
# NameError: name 'motionChartDemo' is not defined

# %% [markdown]
# # A more detailed look at the options

# %% [markdown]
# ### 1. Use the column names from the dataframe to define which variable to use

# %%
mc = MotionChart(df = df,
              key = 'Year',
              x = 'Region',
              y = 'Happiness',
            yscale='quadratic',
              color = 'Region',
              category = 'Region')
mc.to_browser()

# %% [markdown]
# Remember that clicking on the chart after it is created in the browser also allows you to change the specification.

# %% [markdown]
# ### 2. To send the object to the Jupyter Notebook, to a browser, to the clipboard  and to a html file

# %%
mc.to_notebook()
mc.to_browser()
mc.to_clipboard()
mc.to_file()
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="mc_temp.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-28083161e574> in <module>()
#       2 mc.to_browser()
#       3 mc.to_clipboard()
# ----> 4 mc.to_file()
#
# TypeError: to_file() missing 1 required positional argument: 'path_and_name'

# %% [markdown]
# ### 3. You are free to use the column number instead of the column name

# %% [markdown]
# This is useful if you want to use the index column of the dataframe.

# %%
mc = MotionChart(df = df, 
                 title = "Motion Chart",
                 url = "http://socr.ucla.edu/htmls/HTML5/MotionChart",
                 key = 1,
                 x = 2,
                 y = 3,
                 size = 4, 
                 color = 5,
                 category = 1)

# %% [markdown]
# ### 4. Offline?

# %% [markdown]
# It is possible to use create and show motionCharts without an internet connection. This requires that you first install the folders with the javascript files on your local machine (copy the "css" and "js" folders and the content from https://github.com/hmelberg/motionchart). Next, when defining a motion chart you tell it the path to the local folder where the required files are like this:

# %%
mChart = MotionChart(dataframe, url = "(path to your folder with the motion chart js and css)")

# %% [markdown]
# ## List of options and defaults

# %%
mc = MotionChart(
                    df = df, 
                    title = "Motion Chart",
                    url = "http://socr.ucla.edu/htmls/HTML5/MotionChart",
                    key = 1,
                    x = 2,
                    y = 3,
                    size = 4, 
                    color = 5,
                    category = 1,
                    xscale='linear',
                    yscale='linear',
                    play = 'true',
                    loop = 'false',
                    width = 800,
                    height = 600,
                    varLabels=None)

# %% [markdown]
# ## Explained

# %% [markdown]
# **df**
#     # specifies the name of the pandas dataframe used to create the motion chart, default is df
#
# **title**
#     # string. The title of the chart (text, string)
#
# **url             **
#     # string. url to folder with js and css files; can be local, default is external (requires web)
#
# **key**
#     # string or integer. the column number of the "play" variable (does not have to be time)
#
# **x**
#     # string or integer. number (integer) or name (text, string) of the x-variable in the chart
#
# **y**
#     # string or integer. number (integer) or name (text, string) of the x-variable in the chart
#
# **size**
#     # name (string) or column number of the variable used to determine the size of the circles
#
# **color**
#     # name (string) or column number of the variable used to determine the color of the circles
#
# **category**
#     # name (string) or column number of the variable used to describe the category
#
# **xscale**
#     # Scale for x-variable, default 'linear'. Options: 'log', 'sqrt', 'log', 'quadnomial', 'ordinal'
#
# **yscale**
#     # Scale for y-variable, default 'linear'. Options: 'log', 'sqrt', 'log', 'quadnomial', 'ordinal'
#
# **play**
#     # string. 'true' or 'false' (default, false). Determines whether the motion starts right away
#
# **loop**
#     # string. 'true' or 'false' (default, false). Determines whether the motion keeps repeating
#
# **width**
#     # integer. width of chart in pixels, default 800
#
# **height**
#     # integer. height of chart in pixels, default 400
#
# **varLabels**
#     # list. list of labels for columns (default is column headers of dataframe,
#     # must be of same length as the number of columns in the dataframe, including the index columns

# %% [markdown]
# ## Acknowledgements and more information

# %% [markdown]
# See https://github.com/RamyElkest/SocrMotionChartsHTML5 for more information about the javascript which builds the chart<BR>
# See also https://github.com/psychemedia/dataviz4development/tree/master/SocrMotionCharts<BR>
# For more bakcground, and java version, see http://www.amstat.org/publications/jse/v18n3/dinov.pdf<BR>
